# %%
# %matplotlib inline
from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
import pandas as pd
import numpy as np
import heatmap as hm
import matplotlib.pyplot as plt

# %%
ivis = hm.IVIS()
ivis.gt_df.head()
# Out:
#         eventid  year             country                       region  \
# 0  197000000001  1970  Dominican Republic  Central America & Caribbean
# 1  197000000002  1970              Mexico                North America
# 2  197001000001  1970         Philippines               Southeast Asia
# 3  197001000002  1970              Greece               Western Europe
# 4  197001000003  1970               Japan                    East Asia
#
#     latitude   longitude                      attacktype  kills  wounds  \
# 0  18.456792  -69.951164                   Assassination      1       0
# 1  19.432608  -99.133207     Hostage Taking (Kidnapping)      0       0
# 2  15.478598  120.599741                   Assassination      1       0
# 3  37.983773   23.728157               Bombing/Explosion      0       0
# 4  33.580412  130.396361  Facility/Infrastructure Attack      0       0
#
#    casualties
# 0           1
# 1           0
# 2           1
# 3           0
# 4           0

# %%
#kind of similar to what I have in the dot plot notebook - 
#do I want to make this a function?

# %%
ivis.gt_df.describe()
# Out:
#             eventid           year       latitude      longitude  \
# count  1.567720e+05  156772.000000  156772.000000  156772.000000
# mean   2.000541e+11    2000.474083      22.522501      23.512593
# std    1.298283e+09      12.982397      19.335023      59.170005
# min    1.970000e+11    1970.000000     -53.154613    -176.176447
# 25%    1.989082e+11    1989.000000       8.592200      -0.126236
# 50%    2.005071e+11    2005.000000      30.587291      38.650509
# 75%    2.013060e+11    2013.000000      34.610591      67.584889
# max    2.015123e+11    2015.000000      74.633553     179.366667
#
#                kills         wounds     casualties
# count  156772.000000  156772.000000  156772.000000
# mean        2.221156       2.806636       5.027792
# std        11.102675      21.686324      26.198865
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       1.000000
# 75%         2.000000       1.000000       4.000000
# max      1500.000000    5500.000000    5513.000000

# %%
bubble_chart_features = ['year', 'country', 'region', 'casualties']

gtd_bubble = ivis.gt_df[bubble_chart_features]

# %%
gtd_bubble.describe()
# Out:
#                 year     casualties
# count  156772.000000  156772.000000
# mean     2000.474083       5.027792
# std        12.982397      26.198865
# min      1970.000000       0.000000
# 25%      1989.000000       0.000000
# 50%      2005.000000       1.000000
# 75%      2013.000000       4.000000
# max      2015.000000    5513.000000

# %%
#change to use Viola's make_five_year_range (add 5 to hers)?

def create_range(series_to_group, group_size):
    '''Turns a series into groups of a specified size'''
    bins = np.arange(min(series_to_group) - group_size, max(series_to_group) + group_size, group_size)
    ranges = pd.cut(series_to_group, bins)
    ranges.name = series_to_group.name + ' ranges'
    return ranges

# %%
def replace_series_with_range(data, series_to_group, group_size):
    '''Removes year column and merges range column'''
    ranges = create_range(series_to_group, group_size)
    data_replaced = pd.concat([data, pd.DataFrame(ranges)], axis = 1).drop(series_to_group.name, 1)
    return data_replaced

gtd_bubble.head()
# Out:
#    year             country                       region  casualties
# 0  1970  Dominican Republic  Central America & Caribbean           1
# 1  1970              Mexico                North America           0
# 2  1970         Philippines               Southeast Asia           1
# 3  1970              Greece               Western Europe           0
# 4  1970               Japan                    East Asia           0

# %%
gtd_bubble = replace_series_with_range(gtd_bubble, gtd_bubble['year'], 5)
gtd_bubble.head()
# Out:
#               country                       region  casualties   year ranges
# 0  Dominican Republic  Central America & Caribbean           1  (1965, 1970]
# 1              Mexico                North America           0  (1965, 1970]
# 2         Philippines               Southeast Asia           1  (1965, 1970]
# 3              Greece               Western Europe           0  (1965, 1970]
# 4               Japan                    East Asia           0  (1965, 1970]

# %%
#Need to update dot plot with these functions

# %%
def group_by_columns(data, group_by_columns, column_to_agg):
    '''Takes a list of column names and a column to count and counts rows by those column name, including nulls'''
    all_columns = group_by_columns + [column_to_agg]
    data.loc[:, column_to_agg] = data.loc[:, column_to_agg].fillna(value=0)
    data = data.loc[:,all_columns]
    grouped = data.groupby(group_by_columns)
    return grouped

# %%
def sum_by_groups(grouped):
    '''Takes output of group function and sums data'''
    sums = grouped.sum().dropna()
    sums.columns = ['sum']
    return sums

# %%
def count_by_groups(grouped):
    '''Takes output of group function and counts data'''
    counts = grouped.count().dropna()
    counts.columns = ['count']
    return counts

# %%
#Need to deal with error handling for all this stuff
class Bubble_Chart_Data():
    def __init__(self, data, bubble_id, color, user_filter, values):
        '''Defines attributes of the bubble chart'''
        self.data = data
        self.bubble_id = bubble_id
        self.color = color
        self.user_filter = user_filter
        self.values = values
        self.new_data = data
        self.groups = group_by_columns(self.data, [self.bubble_id], self.values)
        self.subgroups = group_by_columns(self.data, [self.bubble_id, self.color, self.user_filter], self.values)
    
    def count_by_subgroup(self):
        '''Uses group from init function to create a count'''
        return count_by_groups(self.subgroups)
        
    def sum_by_subgroup(self):
        '''Uses sum from init function to create a sum'''
        return sum_by_groups(self.subgroups)
    
    def aggregate_by_subgroup(self):
        '''Returns sum and count merged together'''
        self.new_data = pd.concat((self.count_by_subgroup(), self.sum_by_subgroup()), axis=1, join='outer')
        self.new_data.columns = ['attacks', 'total ' + self.values]
        self.new_data.reset_index(level=self.color, inplace=True)
        
    def count_by_group(self):
        '''Returns the sum by groups (ignores user filters)'''
        return count_by_groups(self.groups)
    
    def set_bubble_size(self, bubble_size, new_col_name):
        '''bubble size must be a series with the bubble_id as the index'''
        #want to be able to input a new column name when you do this
        self.new_data = pd.DataFrame(bubble_size).join(self.new_data, how='inner')
        #self.new_data.columns 
        self.bubble_size = new_col_name #currently assumes 1 column
        
    def add_color_dict(self):
        '''Creates a dictionary that maps the color variable to numbers'''
        #You can call this whenever without error, but once you aggregate again, the column will disappear
        #http://stackoverflow.com/questions/14885895/color-by-column-values-in-matplotlib
        color_cats = self.data[self.color].unique()
        colors = np.linspace(0, 1, len(color_cats))
        colordict = dict(zip(color_cats, colors))  
        self.new_data['color'] = self.new_data[self.color].apply(lambda x: colordict[x])
        
    def filter_for_user(self, user_input):
        '''Selects the part of the data that the user selected'''
        #This assumes you've already run agg by bubbleID, should also handle key error
        self.new_data = self.new_data.loc[(slice(None), user_input), :]

# %%
bubble_chart = Bubble_Chart_Data(gtd_bubble, 'country', 'region', 'year ranges', 'casualties')

# %%
bubble_chart.aggregate_by_subgroup()

# %%
bubble_chart.set_bubble_size(bubble_chart.count_by_group(), 'All-Time Attacks')

# %%
bubble_chart.new_data.head()
# Out:
#                           count      region  attacks  total casualties
# country     year ranges
# Afghanistan (1970, 1975]   9690  South Asia      1.0               1.0
#             (1975, 1980]   9690  South Asia      3.0              54.0
#             (1985, 1990]   9690  South Asia     24.0             464.0
#             (1990, 1995]   9690  South Asia     81.0             496.0
#             (1995, 2000]   9690  South Asia     29.0             269.0

# %%
def process_bubble_chart_data():
    bubble_chart = Bubble_Chart_Data(gtd_bubble, 'country', 'region', 'year ranges', 'casualties')
    bubble_chart.aggregate_by_subgroup()
    bubble_chart.set_bubble_size(bubble_chart.count_by_group(), 'all-time attacks')
    bubble_chart.add_color_dict()
    return bubble_chart
    
def select_bubble_chart_year(year_range, bubble_chart):
    bubble_chart.filter_for_user(year_range)
    return bubble_chart

# %%
bubble_chart = process_bubble_chart_data()

bubble_chart = select_bubble_chart_year('(2010, 2015]', bubble_chart)

bubble_chart.new_data
# Out:
#                                        count                       region  \
# country                  year ranges
# Afghanistan              (2010, 2015]   9690                   South Asia
# Albania                  (2010, 2015]     77               Eastern Europe
# Algeria                  (2010, 2015]   2720   Middle East & North Africa
# Argentina                (2010, 2015]    804                South America
# Armenia                  (2010, 2015]     22                 Central Asia
# Australia                (2010, 2015]     88        Australasia & Oceania
# Austria                  (2010, 2015]    106               Western Europe
# Azerbaijan               (2010, 2015]     45                 Central Asia
# Bahamas                  (2010, 2015]      5  Central America & Caribbean
# Bahrain                  (2010, 2015]    182   Middle East & North Africa
# Bangladesh               (2010, 2015]   1513                   South Asia
# Belarus                  (2010, 2015]     13               Eastern Europe
# Belgium                  (2010, 2015]    142               Western Europe
# Belize                   (2010, 2015]      8  Central America & Caribbean
# Bhutan                   (2010, 2015]      6                   South Asia
# Bolivia                  (2010, 2015]    314                South America
# Bosnia-Herzegovina       (2010, 2015]    159               Eastern Europe
# Brazil                   (2010, 2015]    267                South America
# Bulgaria                 (2010, 2015]     51               Eastern Europe
# Burkina Faso             (2010, 2015]      9           Sub-Saharan Africa
# Burundi                  (2010, 2015]    504           Sub-Saharan Africa
# Cambodia                 (2010, 2015]    258               Southeast Asia
# Cameroon                 (2010, 2015]    180           Sub-Saharan Africa
# Canada                   (2010, 2015]     76                North America
# Central African Republic (2010, 2015]    202           Sub-Saharan Africa
# Chad                     (2010, 2015]     80           Sub-Saharan Africa
# Chile                    (2010, 2015]   2334                South America
# China                    (2010, 2015]    242                    East Asia
# Colombia                 (2010, 2015]   8077                South America
# Croatia                  (2010, 2015]     57               Eastern Europe
# ...                                      ...                          ...
# Senegal                  (2010, 2015]    118           Sub-Saharan Africa
# Serbia                   (2010, 2015]     11               Eastern Europe
# Somalia                  (2010, 2015]   2890           Sub-Saharan Africa
# South Africa             (2010, 2015]   1957           Sub-Saharan Africa
# South Korea              (2010, 2015]     37                    East Asia
# South Sudan              (2010, 2015]    111           Sub-Saharan Africa
# Spain                    (2010, 2015]   3239               Western Europe
# Sri Lanka                (2010, 2015]   2982                   South Asia
# Sudan                    (2010, 2015]    688           Sub-Saharan Africa
# Sweden                   (2010, 2015]    102               Western Europe
# Switzerland              (2010, 2015]    107               Western Europe
# Syria                    (2010, 2015]   1468   Middle East & North Africa
# Taiwan                   (2010, 2015]     47                    East Asia
# Tajikistan               (2010, 2015]    184                 Central Asia
# Tanzania                 (2010, 2015]     50           Sub-Saharan Africa
# Thailand                 (2010, 2015]   3338               Southeast Asia
# Trinidad and Tobago      (2010, 2015]     22  Central America & Caribbean
# Tunisia                  (2010, 2015]     92   Middle East & North Africa
# Turkey                   (2010, 2015]   3557   Middle East & North Africa
# Turkmenistan             (2010, 2015]      2                 Central Asia
# Uganda                   (2010, 2015]    366           Sub-Saharan Africa
# Ukraine                  (2010, 2015]   1583               Eastern Europe
# United Arab Emirates     (2010, 2015]     22   Middle East & North Africa
# United Kingdom           (2010, 2015]   4992               Western Europe
# United States            (2010, 2015]   2693                North America
# Uzbekistan               (2010, 2015]     21                 Central Asia
# Venezuela                (2010, 2015]    269                South America
# West Bank and Gaza Strip (2010, 2015]   1990   Middle East & North Africa
# Yemen                    (2010, 2015]   2598   Middle East & North Africa
# Zimbabwe                 (2010, 2015]     98           Sub-Saharan Africa
#
#                                        attacks  total casualties     color
# country                  year ranges
# Afghanistan              (2010, 2015]   7077.0           43203.0  0.909091
# Albania                  (2010, 2015]      7.0               3.0  0.545455
# Algeria                  (2010, 2015]    107.0             450.0  0.727273
# Argentina                (2010, 2015]      6.0               2.0  0.454545
# Armenia                  (2010, 2015]      3.0               2.0  1.000000
# Australia                (2010, 2015]     16.0              13.0  0.818182
# Austria                  (2010, 2015]      2.0               2.0  0.272727
# Azerbaijan               (2010, 2015]      3.0               1.0  1.000000
# Bahamas                  (2010, 2015]      1.0               0.0  0.000000
# Bahrain                  (2010, 2015]    138.0             158.0  0.727273
# Bangladesh               (2010, 2015]    765.0            1107.0  0.909091
# Belarus                  (2010, 2015]      4.0             174.0  0.545455
# Belgium                  (2010, 2015]      3.0               9.0  0.272727
# Belize                   (2010, 2015]      1.0               0.0  0.000000
# Bhutan                   (2010, 2015]      2.0               2.0  0.909091
# Bolivia                  (2010, 2015]      1.0               2.0  0.454545
# Bosnia-Herzegovina       (2010, 2015]     11.0              15.0  0.545455
# Brazil                   (2010, 2015]     12.0               8.0  0.454545
# Bulgaria                 (2010, 2015]     10.0              38.0  0.545455
# Burkina Faso             (2010, 2015]      6.0              16.0  0.636364
# Burundi                  (2010, 2015]    116.0             565.0  0.636364
# Cambodia                 (2010, 2015]      2.0               0.0  0.181818
# Cameroon                 (2010, 2015]    155.0            2202.0  0.636364
# Canada                   (2010, 2015]     14.0              15.0  0.090909
# Central African Republic (2010, 2015]    169.0            1571.0  0.636364
# Chad                     (2010, 2015]     28.0             739.0  0.636364
# Chile                    (2010, 2015]     30.0              31.0  0.454545
# China                    (2010, 2015]     73.0            1239.0  0.363636
# Colombia                 (2010, 2015]    722.0            1850.0  0.454545
# Croatia                  (2010, 2015]      2.0               1.0  0.545455
# ...                                        ...               ...       ...
# Senegal                  (2010, 2015]     23.0             105.0  0.636364
# Serbia                   (2010, 2015]      3.0               3.0  0.545455
# Somalia                  (2010, 2015]   2106.0            8254.0  0.636364
# South Africa             (2010, 2015]     39.0              67.0  0.636364
# South Korea              (2010, 2015]      1.0               1.0  0.363636
# South Sudan              (2010, 2015]    111.0            2286.0  0.636364
# Spain                    (2010, 2015]      9.0               1.0  0.272727
# Sri Lanka                (2010, 2015]     45.0             115.0  0.909091
# Sudan                    (2010, 2015]    439.0            2229.0  0.636364
# Sweden                   (2010, 2015]     44.0               9.0  0.272727
# Switzerland              (2010, 2015]      5.0               2.0  0.272727
# Syria                    (2010, 2015]   1319.0           19119.0  0.727273
# Taiwan                   (2010, 2015]      2.0               0.0  0.363636
# Tajikistan               (2010, 2015]      9.0              34.0  1.000000
# Tanzania                 (2010, 2015]     32.0             162.0  0.636364
# Thailand                 (2010, 2015]   1631.0            4175.0  0.181818
# Trinidad and Tobago      (2010, 2015]      4.0               0.0  0.000000
# Tunisia                  (2010, 2015]     73.0             388.0  0.727273
# Turkey                   (2010, 2015]    788.0            2821.0  0.727273
# Turkmenistan             (2010, 2015]      1.0               5.0  1.000000
# Uganda                   (2010, 2015]     20.0             124.0  0.636364
# Ukraine                  (2010, 2015]   1544.0            4753.0  0.545455
# United Arab Emirates     (2010, 2015]      3.0               1.0  0.727273
# United Kingdom           (2010, 2015]    453.0             103.0  0.272727
# United States            (2010, 2015]    110.0             580.0  0.090909
# Uzbekistan               (2010, 2015]      1.0               0.0  1.000000
# Venezuela                (2010, 2015]      8.0               5.0  0.454545
# West Bank and Gaza Strip (2010, 2015]    487.0             614.0  0.727273
# Yemen                    (2010, 2015]   2283.0           12449.0  0.727273
# Zimbabwe                 (2010, 2015]      5.0               2.0  0.636364
#
# [134 rows x 5 columns]

# %%
def construct_interval(year):
    return '('+ str(year - 5) + ', ' + str(year) + ']'

# %%
bubble_chart.new_data.head()
# Out:
#                           count                      region  attacks  \
# country     year ranges
# Afghanistan (2010, 2015]   9690                  South Asia   7077.0
# Albania     (2010, 2015]     77              Eastern Europe      7.0
# Algeria     (2010, 2015]   2720  Middle East & North Africa    107.0
# Argentina   (2010, 2015]    804               South America      6.0
# Armenia     (2010, 2015]     22                Central Asia      3.0
#
#                           total casualties     color
# country     year ranges
# Afghanistan (2010, 2015]           43203.0  0.909091
# Albania     (2010, 2015]               3.0  0.545455
# Algeria     (2010, 2015]             450.0  0.727273
# Argentina   (2010, 2015]               2.0  0.454545
# Armenia     (2010, 2015]               2.0  1.000000

# %%
bubble_chart.new_data['attacks'][0]
# Out:
# 7077.0

# %%
bubble_chart.new_data.head()
# Out:
#                   country  count                      region  attacks  \
# year ranges
# (2010, 2015]         Iraq  18770  Middle East & North Africa  12262.0
# (2010, 2015]     Pakistan  12768                  South Asia   8258.0
# (2010, 2015]  Afghanistan   9690                  South Asia   7077.0
# (2010, 2015]        India   9940                  South Asia   3690.0
# (2010, 2015]      Nigeria   2888          Sub-Saharan Africa   2486.0
#
#               total casualties     color
# year ranges
# (2010, 2015]           90932.0  0.727273
# (2010, 2015]           29204.0  0.909091
# (2010, 2015]           43203.0  0.909091
# (2010, 2015]            5651.0  0.909091
# (2010, 2015]           24251.0  0.636364

# %%
bubble_chart.new_data = bubble_chart.new_data.sort_values('attacks', ascending=False)

# %%
import matplotlib.pyplot as plt

def create_bubble_chart(year):
    
    bubble_chart = process_bubble_chart_data()
    
    bubble_chart = select_bubble_chart_year(construct_interval(year), bubble_chart)
    
    bubble_chart.new_data.reset_index(level=bubble_chart.bubble_id, inplace=True)
    
    bubble_chart.new_data = bubble_chart.new_data.sort_values('attacks', ascending=False)
    
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1, axisbg='white')
    
    N = 100
    
    #Countries = list(bubble_chart.new_data.index.get_level_values(0))
    
    ax.set_xlabel('Attacks')
    #ax.set_xlim([0, 14000])
    ax.set_ylabel('Total Casualties')
    #ax.set_ylim([0, 100000])
    #need to change these column names to general
    scatter = ax.scatter(bubble_chart.new_data['attacks'], 
                         bubble_chart.new_data['total casualties'],
                         (bubble_chart.new_data['count']/100)**2,        # I made a tiny change on this line :) -Viola
                         c = bubble_chart.new_data['color'], 
                         cmap ='viridis',         # 'RdYlBu', 'viridis', 'cool_r', 'Blues', 'BuPu', 'YlGnBu'   - Viola
                         alpha = 0.5)
    
    bubble_chart.new_data.sort_values('attacks', ascending=False).iloc[0:20]
    
    for i in range(0, 10):
        plt.annotate(bubble_chart.new_data['country'].iloc[i], 
                     xy = (bubble_chart.new_data['attacks'].iloc[i], bubble_chart.new_data['total casualties'].iloc[i]),
                     xytext=(18,-5),
                     textcoords='offset points',
                     color='darkslategrey')

    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)
    
    plt.show()

# %%
bubble_chart.new_data

# %%
bubble_chart.new_data.reset_index(level=bubble_chart.bubble_id, inplace=True)

# %%
create_bubble_chart(2005)

# %%
#I don't like how the axes change as you scroll around
#but if you set it to the max, most of the data is super scrunched on one end

'''
Me neither. 
I tried making the bubble larger and the slider longer. 
Hope it made the differences a little bit easier to observe.

Also I set the the starting value as 1995, cuz this year seems the most scattered.

Overall, I love it! So pretty and functional!!

Two suggestions:

1. Can you please add a title on top of the chart?
2. Would it be better if attaching a color palette notation (something like the pic below), 
   to give users a hint what the colors mean?
'''
import seaborn as sns
sns.palplot(sns.cubehelix_palette(20))

# %%
# I made some changes on this cell :) 
# -Viola


bb_yr = widgets.IntSlider(min=1975,max=2015,step=5,value=1995)
bb_yr.layout.width = '80%'
interact(create_bubble_chart, year=bb_yr)
# Out:
# <function __main__.create_bubble_chart>

# %% [markdown]
# Also considered doing a bubble chart where the x axis is percentage change in # killed, y axis is percentage change in # attacks, and size of bubble is # incidents

# %%
#this is useful in general, don't make it specific to bubble chart
def create_total(to_sum, sum_by):
    '''takes two series of the same length, sums one by the other, returns a series with the result'''
    data = pd.concat([sum_by, to_sum], axis = 1)
    totaled = pd.pivot_table(data, index = sum_by.name, aggfunc=sum)
    totaled.columns = ['total ' + to_sum.name]
    return pd.Series(totaled['total ' + to_sum.name])
