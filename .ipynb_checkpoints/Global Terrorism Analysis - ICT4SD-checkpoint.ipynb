# %% [markdown]
# [![Center for Data Science - New York University](https://raw.githubusercontent.com/violaciao/IVIS-GTD/master/Header.png)](https://ict4sd.github.io/2016/11/11/Project_Global_Terror/)
# <span class="caption text-muted">  </span>

# %% [markdown]
# <font color='skyblue'>
#     <h1 align="center">
#         <i class="fa fa-3x">
#             <h4>Global Terrorism Analysis</h4>
#         </i>
#     </h1>
# </font>
#
# <font color='skyblue'>
#     <h1 align="center">
#         <i class="fa fa-spinner fa-spin fa-3x fa-fw"></i>
#         <span class="sr-only">Loading...</span>
#     </h1>
# </font>

# %% [markdown]
# <div class="alert alert-info fade in">
#     <a href="#" class="close" data-dismiss="alert">&times;</a>
#     <strong>Go To</strong> <font color='Medium Sea Green'>[User Manual](https://docs.google.com/document/d/1KNxP-8Ccey1tM1sOBJRB7VyB3rjtPe2gbDFlHtD_iCk/edit?usp=sharing)</font>
# </div>

# %% [markdown]
# <font color='steelblue'>
#     <h1 align="center">
#         <i class="fa fa-globe fa-2x"> Statistical Overview</i>
#     </h1>
# </font>

# %%
# %matplotlib inline
from IVIS import *

# %%
IVIS_AL()
# Out:
# <h1 >             Statistical Analysis - Terror Attacks in The Whole World
#                                   * * *
# --+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--
# During the year 1970 to 2015:
#     - The year with the most attacks:        2014
#              * 16840 times of terror attacks in The Whole World in this year
#     - The year with the most damages:        2014
#              * The Whole World suffered the most severe damage by terrorism in this year.
#              * 84089 people were killed or wounded.
#              * 16840 times of terror attacks in The Whole World in this year
#     - Occurrence of Terror Attacks
#              * The total number:              156772
#              * The annual average:            3483
#              * The standard deviation:        3441.55354249
#     - Casualties
#          1) The total number:                 788217
#              * kills                          348215
# ...

# %% [markdown]
# <div class="alert alert-info"> <div>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>     </font></h1>

# %% [markdown]
# <font color='steelblue'>
#     <h1 align="center">
#         <i class="fa fa-globe fa-2x"> Geographic Overview Over Time</i>
#     </h1>
# </font>

# %%
IVIS_CHR()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# <h1 align="center"><font color='steelblue'>     </font></h1>

# %% [markdown]
# <font color='steelblue'>
#     <h1 align="center">
#         <i class="fa fa-globe fa-2x"> Geographic Attack Density</i>
#     </h1>
# </font>

# %%
IVIS_GEO()

# %% [markdown]
# <h1 align="center"><font color='steelblue'>    </font></h1>

# %% [markdown]
# <font color='steelblue'>
#     <h1 align="center">
#         <i class="fa fa-globe fa-2x"> Regional Heatmap Over Time</i>
#     </h1>
# </font>

# %%
IVIS_HT()

# %% [markdown]
# <h1 align="center"><font color='steelblue'>     </font></h1>

# %% [markdown]
# <font color='steelblue'>
#     <h1 align="center">
#         <i class="fa fa-globe fa-2x"> Bubble Chart Over Time</i>
#     </h1>
# </font>

# %%
IVIS_BC()

# %% [markdown]
# [![ICT4SD supports the Sustainable Development Goals.](https://ict4sd.github.io/img/E_Logo_No%20UN%20Emblem-01.png)](https://ict4sd.github.io/2016/11/11/Project_Global_Terror/)
# <span class="caption text-muted"> </span>

# %% [markdown]
# <h3 align="center"><font color='skyblue'>Thank you for your experience.</font></h3>
# <h3 align="center"><font color='skyblue'>Please let us know what you think. We'd love to hear it.</font></h3>
# <h4 align="center"><font color='darkgrey'>Viola & Caroliner</font></h4>

# %% [markdown]
# <div class="container">
#         <div class="row">
#             <div class="col-lg-4 col-lg-offset-3 col-md-1 col-md-offset-1">
#                 <ul class="list-inline text-center">
#                     <li>
#                         <a href="https://www.facebook.com/viola.x.ciao">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-facebook fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://github.com/violaciao">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-github fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="mailto:xianzhi.cao@nyu.edu">
#                             <span class="fa-stack fa-lg">
#                                 <i class="fa fa-circle fa-stack-2x"></i>
#                                 <i class="fa fa-envelope fa-stack-1x fa-inverse"></i>
#                             </span>
#                         </a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </div>

# %% [markdown]
# ###
